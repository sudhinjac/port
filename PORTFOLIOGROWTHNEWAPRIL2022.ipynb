# %%
import numpy as np
from io import StringIO
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_datareader
import datetime
import pandas_datareader.data as web
from scipy.stats import norm

dfticker = pd.read_csv("//Users//sudhinjacob//stocks//QUALGR1.csv", index_col = False)
length = len(dfticker)

# %%
dfticker1 = pd.read_csv("//Users//sudhinjacob//stocks//QUALGR2.csv", index_col = False)

# %%
df2 = dfticker.loc[~dfticker['Ticker'].isin(dfticker1)]
df2.to_csv("QUALITYMERGEINDIAN.csv")

# %%
df2
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 0           13       TANLA.NS  0.023990    0.032572  0.736524    55.504592
# 1           49    LIKHITHA.NS  0.025090    0.032572  0.770277    47.244972
# 2            5    SAREGAMA.NS  0.028091    0.032572  0.862401    54.585428
# 3           16  TIPSINDLTD.NS  0.017286    0.032572  0.530693    55.886067
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 5            6        CDSL.NS  0.029653    0.032572  0.910366    38.722572
# 6           42     ESCORTS.NS  0.039362    0.032572  1.208449    42.821157
# 7           25     COFORGE.NS  0.031755    0.032572  0.974907    43.190509
# 8           14    SUMICHEM.NS  0.050317    0.032572  1.544776    41.464499
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 10          32    ADFFOODS.NS  0.031198    0.032572  0.957789    46.360113
# ...

# %%
df2[['Volatility%','Return%']].plot(figsize=[18,10])
# Out:
# <AxesSubplot:>

# %%
df2.sort_values(by='Return%', ascending=False).head(30)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 0           13       TANLA.NS  0.023990    0.032572  0.736524    55.504592
# 1           49    LIKHITHA.NS  0.025090    0.032572  0.770277    47.244972
# 2            5    SAREGAMA.NS  0.028091    0.032572  0.862401    54.585428
# 3           16  TIPSINDLTD.NS  0.017286    0.032572  0.530693    55.886067
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 5            6        CDSL.NS  0.029653    0.032572  0.910366    38.722572
# 6           42     ESCORTS.NS  0.039362    0.032572  1.208449    42.821157
# 7           25     COFORGE.NS  0.031755    0.032572  0.974907    43.190509
# 8           14    SUMICHEM.NS  0.050317    0.032572  1.544776    41.464499
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 10          32    ADFFOODS.NS  0.031198    0.032572  0.957789    46.360113
# ...

# %%
df2.sort_values(by='Volatility%', ascending=True).head(30)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 34           9        PGHH.NS  0.010002    0.032572  0.307072    21.385236
# 36          52      SANOFI.NS  0.010530    0.032572  0.323272    22.159065
# 32          19  HINDUNILVR.NS  0.019710    0.032572  0.605114    23.496325
# 29          24  SCHAEFFLER.NS  0.013994    0.032572  0.429624    25.811873
# 38          59      VSTIND.NS  0.014850    0.032572  0.455909    27.451540
# 30          36  SUPREMEIND.NS  0.017585    0.032572  0.539889    29.805477
# 39          23      CRISIL.NS  0.016092    0.032572  0.494040    29.932612
# 19           7      HONAUT.NS  0.024581    0.032572  0.754656    30.702797
# 18           8   GRINDWELL.NS  0.016811    0.032572  0.516117    30.743962
# 27          44         IGL.NS  0.024600    0.032572  0.755236    31.017558
# 35          27      VGUARD.NS  0.019471    0.032572  0.597771    31.371087
# ...

# %%
plt.figure(figsize=[18,10])
x= df2['Return%']
y = df2['Volatility%']

plt.grid(True)
plt.title('Volatility Return', fontsize=14, color='black')
plt.xlabel("Return",fontsize=12, color='black')
plt.ylabel("Volatility", fontsize=12, color='black') 
plt.scatter(x, y, color='r')
plt.show()

# %%
df2[(df2['Volatility%']<40 ) & (df2['Return%']>15)].sort_values(by='Volatility%',ascending=True)
#df2 = df1.sort_values(by='Return%', ascending=False)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 32          19  HINDUNILVR.NS  0.019710    0.032572  0.605114    23.496325
# 29          24  SCHAEFFLER.NS  0.013994    0.032572  0.429624    25.811873
# 30          36  SUPREMEIND.NS  0.017585    0.032572  0.539889    29.805477
# 19           7      HONAUT.NS  0.024581    0.032572  0.754656    30.702797
# 18           8   GRINDWELL.NS  0.016811    0.032572  0.516117    30.743962
# 27          44         IGL.NS  0.024600    0.032572  0.755236    31.017558
# 23          15    DIVISLAB.NS  0.021091    0.032572  0.647496    33.482537
# 28          11  LALPATHLAB.NS  0.017352    0.032572  0.532715    34.111786
# 11          34  JBCHEPHARM.NS  0.020332    0.032572  0.624196    35.016200
# 12           2  VINATIORGA.NS  0.021598    0.032572  0.663082    35.908133
# 21          58   TIDEWATER.NS  0.018865    0.032572  0.579174    36.289821
# ...

# %%
df2[(df2['Volatility%']<50 ) & (df2['Return%']>15) & (df2['CAGR'] > 20)  ].sort_values(by='Return%',ascending=False).head(35)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 5            6        CDSL.NS  0.029653    0.032572  0.910366    38.722572
# 6           42     ESCORTS.NS  0.039362    0.032572  1.208449    42.821157
# 7           25     COFORGE.NS  0.031755    0.032572  0.974907    43.190509
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 10          32    ADFFOODS.NS  0.031198    0.032572  0.957789    46.360113
# 11          34  JBCHEPHARM.NS  0.020332    0.032572  0.624196    35.016200
# 12           2  VINATIORGA.NS  0.021598    0.032572  0.663082    35.908133
# 15          28        LTTS.NS  0.024731    0.032572  0.759254    38.071003
# 16          48     GULPOLY.NS  0.022711    0.032572  0.697255    45.787486
# 18           8   GRINDWELL.NS  0.016811    0.032572  0.516117    30.743962
# ...

# %%
df2[(df2['Volatility%']<50 ) & (df2['Return%']>15) & (df2['Value at Risk'] <50000)].sort_values(by='Return%',ascending=False)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 1           49    LIKHITHA.NS  0.025090    0.032572  0.770277    47.244972
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 5            6        CDSL.NS  0.029653    0.032572  0.910366    38.722572
# 6           42     ESCORTS.NS  0.039362    0.032572  1.208449    42.821157
# 7           25     COFORGE.NS  0.031755    0.032572  0.974907    43.190509
# 8           14    SUMICHEM.NS  0.050317    0.032572  1.544776    41.464499
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 10          32    ADFFOODS.NS  0.031198    0.032572  0.957789    46.360113
# 11          34  JBCHEPHARM.NS  0.020332    0.032572  0.624196    35.016200
# 12           2  VINATIORGA.NS  0.021598    0.032572  0.663082    35.908133
# 15          28        LTTS.NS  0.024731    0.032572  0.759254    38.071003
# ...

# %%
plt.figure(figsize=[18,10])
x= df2['Return%']
y = df2['Value at Risk']

plt.grid(True)
plt.title('VAR Return', fontsize=18, color='black')
plt.xlabel("Return",fontsize=18, color='black')
plt.ylabel("Value at Risk", fontsize=18, color='black') 
plt.scatter(x, y )
plt.show()

# %%
df2[(df2['Volatility%']>50 ) & (df2['Return%']>15)].sort_values(by='Volatility%',ascending=True)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 24          43  SHARDAMOTR.NS  0.030653    0.032572  0.941061    51.220904
# 13          40  CAPLIPOINT.NS  0.029571    0.032572  0.907852    52.273268
# 17          47     RPGLIFE.NS  0.030953    0.032572  0.950267    52.373757
# 2            5    SAREGAMA.NS  0.028091    0.032572  0.862401    54.585428
# 0           13       TANLA.NS  0.023990    0.032572  0.736524    55.504592
# 3           16  TIPSINDLTD.NS  0.017286    0.032572  0.530693    55.886067
# 14          17         FCL.NS  0.030607    0.032572  0.939649    62.262481
#
#       Return%  Sharp Ratio       CAGR     MAXDD%  Value at Risk
# 24  22.261309     0.336997  22.364715  81.827320   68383.892166
# 13  30.894724     0.495372  36.175677  74.085833   61904.005255
# 17  27.095621     0.421883  31.102028  73.685660   65934.399212
# 2   53.638438     0.891052  70.930420  77.013541   33208.522162
# ...

# %%
df2[(df2['Volatility%']<60 ) & (df2['Return%']>15)].sort_values(by='Return%',ascending=False).head(35)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 0           13       TANLA.NS  0.023990    0.032572  0.736524    55.504592
# 1           49    LIKHITHA.NS  0.025090    0.032572  0.770277    47.244972
# 2            5    SAREGAMA.NS  0.028091    0.032572  0.862401    54.585428
# 3           16  TIPSINDLTD.NS  0.017286    0.032572  0.530693    55.886067
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 5            6        CDSL.NS  0.029653    0.032572  0.910366    38.722572
# 6           42     ESCORTS.NS  0.039362    0.032572  1.208449    42.821157
# 7           25     COFORGE.NS  0.031755    0.032572  0.974907    43.190509
# 8           14    SUMICHEM.NS  0.050317    0.032572  1.544776    41.464499
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 10          32    ADFFOODS.NS  0.031198    0.032572  0.957789    46.360113
# ...

# %%
df2[(df2['Volatility%']<50 ) & (df2['Return%']>15) & (df2['CAGR'] > 20) & (df2['MAXDD%'] < 50)  ].sort_values(by='Return%',ascending=False).head(35)
# Out:
#     Unnamed: 0         Ticker   Cov_mar  Market_var      Beta  Volatility%  \
# 4           10  NAVINFLUOR.NS  0.025700    0.032572  0.789011    41.204109
# 9            1         IEX.NS  0.021003    0.032572  0.644815    37.480001
# 11          34  JBCHEPHARM.NS  0.020332    0.032572  0.624196    35.016200
# 12           2  VINATIORGA.NS  0.021598    0.032572  0.663082    35.908133
# 15          28        LTTS.NS  0.024731    0.032572  0.759254    38.071003
# 18           8   GRINDWELL.NS  0.016811    0.032572  0.516117    30.743962
# 19           7      HONAUT.NS  0.024581    0.032572  0.754656    30.702797
# 20           4   ESABINDIA.NS  0.025908    0.032572  0.795382    41.643268
# 22          21      NAUKRI.NS  0.023504    0.032572  0.721579    38.859478
# 25          26  AMRUTANJAN.NS  0.025977    0.032572  0.797522    40.340114
# 27          44         IGL.NS  0.024600    0.032572  0.755236    31.017558
#
#       Return%  Sharp Ratio       CAGR     MAXDD%  Value at Risk
# ...
